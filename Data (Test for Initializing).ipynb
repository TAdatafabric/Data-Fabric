# %% [markdown]
# Import Library

# %%
import pandas as pd #dataframe library
import numpy as np #numeric library
import matplotlib.pyplot as plt #plot library
import seaborn as sns #graphic library

#evaluation library
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, recall_score, precision_score

# %% [markdown]
# Import Dataset

# %%
data = pd.read_excel('Dataset/Numerical.xlsx')

# %% [markdown]
# Correlation Plot

# %%
data.corr()
# Out:
# C:\Users\Fieril Nur Arham\AppData\Local\Temp\ipykernel_10476\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    service_filter  payment_cat   subs_no  subs_key      b_no  \
# service_filter           1.000000    -0.233765 -0.082592 -0.180282  0.015508
# payment_cat             -0.233765     1.000000  0.385813  0.269619  0.008117
# subs_no                 -0.082592     0.385813  1.000000  0.272948 -0.002046
# subs_key                -0.180282     0.269619  0.272948  1.000000  0.002685
# b_no                     0.015508     0.008117 -0.002046  0.002685  1.000000
# event_action_code       -0.659620     0.067274  0.094492  0.079085  0.008306
# prefix_dom_sk_id         0.223906    -0.122915 -0.034704 -0.102183 -0.012508
# rtd_amt                  0.018703    -0.049808 -0.006110  0.009810 -0.006564
# free_unit               -0.028077     0.016490  0.021185  0.010401 -0.001886
# chrg_unit               -0.121333     0.035403  0.016061  0.013190 -0.002723
# rtd_unit                -0.121332     0.035404  0.016062  0.013190 -0.002723
# usg_unit                -0.121332     0.035404  0.016062  0.013190 -0.002723
# apn                      0.676470    -0.197266 -0.038278  0.023832  0.015176
# disc_amt                      NaN          NaN       NaN       NaN       NaN
#
#                    event_action_code  prefix_dom_sk_id   rtd_amt  free_unit  \
# service_filter             -0.659620          0.223906  0.018703  -0.028077
# payment_cat                 0.067274         -0.122915 -0.049808   0.016490
# subs_no                     0.094492         -0.034704 -0.006110   0.021185
# subs_key                    0.079085         -0.102183  0.009810   0.010401
# b_no                        0.008306         -0.012508 -0.006564  -0.001886
# event_action_code           1.000000          0.164095 -0.025626   0.025447
# prefix_dom_sk_id            0.164095          1.000000 -0.073009   0.030246
# rtd_amt                    -0.025626         -0.073009  1.000000   0.024601
# free_unit                   0.025447          0.030246  0.024601   1.000000
# chrg_unit                   0.035692         -0.053769  0.076157   0.019868
# rtd_unit                    0.035693         -0.053767  0.076158   0.113219
# usg_unit                    0.035693         -0.053767  0.076158   0.113219
# apn                        -0.198893          0.299820  0.140944        NaN
# disc_amt                         NaN               NaN       NaN        NaN
#
#                    chrg_unit  rtd_unit  usg_unit       apn  disc_amt
# service_filter     -0.121333 -0.121332 -0.121332  0.676470       NaN
# payment_cat         0.035403  0.035404  0.035404 -0.197266       NaN
# subs_no             0.016061  0.016062  0.016062 -0.038278       NaN
# subs_key            0.013190  0.013190  0.013190  0.023832       NaN
# b_no               -0.002723 -0.002723 -0.002723  0.015176       NaN
# event_action_code   0.035692  0.035693  0.035693 -0.198893       NaN
# prefix_dom_sk_id   -0.053769 -0.053767 -0.053767  0.299820       NaN
# rtd_amt             0.076157  0.076158  0.076158  0.140944       NaN
# free_unit           0.019868  0.113219  0.113219       NaN       NaN
# chrg_unit           1.000000  1.000000  1.000000 -0.156175       NaN
# rtd_unit            1.000000  1.000000  1.000000 -0.156174       NaN
# usg_unit            1.000000  1.000000  1.000000 -0.156174       NaN
# apn                -0.156175 -0.156174 -0.156174  1.000000       NaN
# disc_amt                 NaN       NaN       NaN       NaN       NaN

# %%
sns.heatmap(data.corr(), cmap="RdBu_r", annot=True)
# Out:
# C:\Users\Fieril Nur Arham\AppData\Local\Temp\ipykernel_10476\2504745011.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cmap="RdBu_r", annot=True)
# <Axes: >
